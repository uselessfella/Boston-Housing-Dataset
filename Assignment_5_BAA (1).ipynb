# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df = pd.read_csv('BostonHousing - BostonHousing.csv')

# %%
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
sns.pairplot(df)

# %%
df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
sns.displot(df, x="ptratio",color='black')
sns.lineplot(x='ptratio', y='crim', data=df,color='yellow')
plt.show()

# %% [markdown]
# According to this graph, what can clearly see is that teachers are corrupt and the teahers are influcening the students into unethical activities and the teachers being involved in those activities too. Therefore, a strict action is needed in the education industry and the teachers should be working the other way around to getting the students to grow up to be a better human being not a criminal.
# ![](https://tenor.com/en-GB/view/alla-hu-akbar-gif-20099105)

# %%
plt.scatter(df['rm'], df['medv'],color='orange')
plt.xlabel('Average number of rooms per dwelling')
plt.ylabel('Median value of owner-occupied homes in $1000s')
plt.show()

# %% [markdown]
# The number of rooms and the median values of the homes increase with a positive coorelation. The price increases with the number of rooms, although there are several disparities as there are a few cases where the rooms are sold at a lower price in the neighbourhood and vicac versa. This may be because of a few other factors which aren't mentioned which affect the prices, some of them may be becuase of the facilities provided in the area or maybe the old sturcutres which need to be reworked or the crime rate or so on.
# ![](https://tenor.com/en-GB/view/willem-dafoe-willem-take-me-home-take-me-home-country-roads-west-virginia-gif-23688545)

# %%
plt.hist(df['rm'], bins=10,color='green')
plt.xlabel('Average number of rooms per dwelling')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# According to this graph, maximum number of houses have 6 rooms in the neighbourhood, and the majority of the houses have a range of rooms between 5 to 7. This means that, there are lesser number of houses with low count of rooms and people prefer having spacious and bigger houses. Another thing which may be inferred is that, people are living in joint families or at least they prefer staying together which gives us a insight on their nature that they are welcoming and prefer living together which gives is good and tells us that they have a good, strong and a united enighbourhood.

# %%
df[['medv']].plot(kind='box',color="red")
plt.title('box plot of Median value of owner-occupied homes in $1000')
plt.xlabel('Median value of owner-occupied homes in $1000s')
plt.ylabel('values')
plt.show()

# %% [markdown]
# Since we see families overpaying for their homes to a very high amount, we can conculde that they have ridiciously good financial background and they are willing to pay premiums  for a few facilities or the neighbourhood of their choice, irrespective of the price factor. Although, in the long run the ROI may not be what they expect it to be, which means they must look after other options as well and keep a check on the financials and such over expenditure may turn out to be a bad thing.

# %%
sns.distplot(df['ptratio'], bins=20,color='cyan')
plt.title('Distnace plot of pupil teacher ratio')
plt.xlabel('Pupil Teacher ratio')
plt.show()
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# The graph clearly depicts the unavailablitiy of teachers in the neighbourhood, and since we saw that the staff members were included in unethical acitivites, that may be a reason as they might have got caught doing such a thing that they were fired, therefore the community should focus on getting more teachers who would share their expertise and knwoledge and guide the students to go on the right path and not indulge into unethical practices.
# Another reason the the student count is more becuase the families are big they may have a bigger family and more children, therefore they should plan better on the family part and also, focus on their children more as they might not be getting enough or the right education which the parents expect.

# %%
sns.lineplot(x='dis', y='nox', data=df,color='Red')
plt.title('remoteness of workspace and the concentration of Nitrogen Oxides' )
plt.xlabel('Weighted distance to employment centers')
plt.ylabel('Nitrogen oxides concentration')
plt.show()

# %% [markdown]
# The working plants are close to the neighbourhood, which means that the air quality near them is pretty low and the families need to take proper precautions for the same. At the same time, we also conclude that the people living farther away from the city are prone to lesser medical issues because they have a better air quality and a safer neighbourhood to live inn, in the terms of air quality and health measures.

# %% [markdown]
# # Multiple Linear Regression

# %%
from sklearn.model_selection import train_test_split

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
x = df.drop('medv',axis=1)
y = df['medv']

# %%
x
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# ...

# %%
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: medv, Length: 506, dtype: float64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=0,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_train_pred = lr.predict(x_train)

# %%
y_pred = lr.predict(x_test)

# %%
y_pred_train = lr.predict(x_train)

# %%
#TRAINING DATA

# %%
plt.xlabel('index')
plt.ylabel('medv')
plt.title('Prediction')

plt.scatter(y_train_pred,y_train)
plt.show()

# %%
#Predictions
len(y_test)
len(y_pred)
print('Y_test prediction is: ', y_test)
print(' ')
print('Y_pred prediction is: ',  y_test)
# Out:
# Y_test prediction is:  329    22.6
# 371    50.0
# 219    23.0
# 403     8.3
# 78     21.2
#        ...
# 56     24.7
# 455    14.1
# 60     18.7
# 213    28.1
# 108    19.8
# Name: medv, Length: 102, dtype: float64
#
# Y_pred prediction is:  329    22.6
# 371    50.0
# 219    23.0
# 403     8.3
# 78     21.2
#        ...
# 56     24.7
# 455    14.1
# 60     18.7
# 213    28.1
# 108    19.8
# Name: medv, Length: 102, dtype: float64

# %%
x_range = [i for i in range(len(y_test))]

# %%
plt.xlabel('index')
plt.ylabel('medv')
plt.title('Prediction')
plt.plot(x_range,y_test)
plt.plot(x_range,y_pred)
plt.legend(["Real", "Predicted"])
plt.show()

# %%
#TESTING DATA

# %%
plt.xlabel('index')
plt.ylabel('medv')
plt.title('Prediction')
plt.scatter(y_pred,y_test)
plt.show()

# %%
#RMSE and MSE values for the Testing Data

# %%
from sklearn.metrics import r2_score,mean_squared_error

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 33.448979997676524

# %%
mse_test = mean_squared_error(y_test,y_pred)

# %%
import math
rmse_test = math.sqrt(mse_test)
print("RMSE:", rmse_test)
# Out:
# RMSE: 5.783509315085134

# %%
#Training Data values for MSE and RMSE

# %%
mean_squared_error(y_train,y_pred_train)
# Out:
# 19.326470203585725

# %%
mse_train = mean_squared_error(y_train,y_pred_train)

# %%
rmse_train = math.sqrt(mse_train)
print("RMSE:", rmse_train)
# Out:
# RMSE: 4.396188144698282

# %%
# Calculate R square vale
r2_score(y_test,y_pred)
# Out:
# 0.589222384918251

# %%
rsq = r2_score(y_test,y_pred)

# %%
print('mean squared error :',mse_test)
print('r square :',rsq)
# Out:
# mean squared error : 33.448979997676524
# r square : 0.589222384918251

# %%
print('Intercept of the model:',lr.intercept_)
print('Coefficient of the line:',lr.coef_)
# Out:
# Intercept of the model: 38.09169492630278
# Coefficient of the line: [-1.19443447e-01  4.47799511e-02  5.48526168e-03  2.34080361e+00
#  -1.61236043e+01  3.70870901e+00 -3.12108178e-03 -1.38639737e+00
#   2.44178327e-01 -1.09896366e-02 -1.04592119e+00  8.11010693e-03
#  -4.92792725e-01]

# %%
fig, ax = plt.subplots()

ax.barh(list(x_train.columns), list(lr.coef_), align='center')
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Coefficients')
ax.set_title('Column weights')

plt.show()

# %%
lr.predict([[0.00632,18.0,2.31,0,0.538,6.575,68.2,4.0900,1,296,15.3,396.90,4.98]])
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([30.49013512])

# %%
def my_function(a,b,c,d,e,f,g,h,i,j,k,l,m):
    temp=[]
    temp.append(lr.predict([[a,b,c,d,e,f,g,h,i,j,k,l,m]]))
    return temp

# %%
my_function(0.00632,20.0,2.31,0,0.538,6.575,65.2,4.0900,1,250,15.3,396.90,4.98)
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# [array([31.09458155])]

# %% [markdown]
# Therefore from the above the we can conclude by saying that, with these following values:
#
#     crimzn = 0.00632
#     zn = 20.0
#     indus = 2.31
#     chas = 0
#     nox = 0.538
#     rm = 6.575
#     age = 65.2
#     dis = 4.0900
#     rad = 1
#     tax = 250
#     ptratio = 15.3
#     b = 396.90
#     lstat = 4.98
#
# The medv value for me will be 30.49949836
